# %% [markdown]
# Güneş Kremi Satış Tahmini:
#
# Giriş:
#
# Bugünün dünyasında veri bilimi, işletmelerin müşterileri hakkında verileri toplaması, analiz etmesi ve kararlarını bu verilere dayandırması açısından oldukça önemlidir. Bu sunumda, geçmiş 10 yılın güneş kremi satış verilerini kullanarak gelecek 2 yılın satış tahminlerini yapmak için SARIMAX modelini kullanacağız.
#
# Veri Ön İşleme:
#
# Verileri okuduktan sonra, ilk adımımız verileri analiz etmek ve ön işleme yapmaktır. Verilerinizi analiz ederken, verilerin tarih ve satış miktarı sütunlarını içerdiğinden emin olun. Verilerinizi geçerli bir zaman serisi oluşturmak için tarihe göre sıralayın. Ayrıca verilerinizi eksik veya bozuk verileri düzelterek temizleyin.
#
# Veri Görselleştirme:
#
# Verileri görselleştirmek, verileri daha iyi anlamak ve gelecekteki trendleri tahmin etmek için önemlidir. Matplotlib veya Seaborn kütüphaneleri kullanarak verilerinizi çizgi grafikleri veya çizgi grafikleri kullanarak görselleştirin.
#
# Modelleme:
#
# Modelleme için SARIMAX modelini kullanacağız. Bu model, zamana bağlı değişkenleri tahmin etmek için kullanılır ve hava durumu tahmini, finansal tahminler ve diğer birçok uygulama için kullanılabilir. SARIMAX modeli, ARIMA modeline benzer, ancak SARIMAX modeli değişkenlere bağlıdır. Bu modeli uygulamak için, statsmodels kütüphanesini kullanacağız.
#
# Sonuç:
#
# Sonuç olarak, SARIMAX modeli kullanarak geçmiş güneş kremi satış verilerini analiz ettik ve gelecek 2 yılın satış tahminlerini yaptık. Bu model, işletmelerin gelecekteki satışları tahmin etmelerine yardımcı olabilir ve iş kararlarını bu tahminlere dayandırabilirler.
#
#
#
# ---------------------------------------------------------
#
# Giriş:
#
# Market sepeti analizi, bir müşterinin bir mağazada hangi ürünleri satın aldığını analiz etmek için kullanılan bir tekniktir. Bu teknik, Apriori algoritmasını kullanarak bir müşterinin bir sepete koyduğu ürünlerin kombinasyonlarını analiz eder. Bu sunumda, 50 farklı ürünün market sepeti analizini yapmak için Apriori algoritmasını kullanacağız.
#
# Veri Ön İşleme:
#
# Verileri okuduktan sonra, ilk adımımız verileri analiz etmek ve ön işleme yapmaktır. Verilerinizin hangi ürünleri içerdiğinden emin olun. Verilerinizi eksik veya bozuk verileri düzelterek temizleyin. Bu verileri daha sonra Apriori algoritmasını kullanarak analiz edeceğiz.
#
# Veri Görselleştirme:
#
# Verileri görselleştirmek, verileri daha iyi anlamak ve gelecekteki trendleri tahmin etmek için önemlidir. Market sepeti analizi için görselleştirme yapmak daha zordur, ancak verilerinizi bazı görselleştirme teknikleri kullanarak görselleştirebilirsiniz. Örneğin, farklı ürünlerin birbiriyle ilişkisini gösteren bir ısı haritası kullanabilirsiniz.
#
# Apriori Algoritması:
#
# Market sepeti analizi için kullanacağımız algoritma Apriori algoritmasıdır. Bu algoritma, bir mağaza sepetindeki farklı ürünlerin kombinasyonlarını analiz eder. Bu algoritmayı uygulamak için, Python'da birkaç farklı kütüphane kullanabilirsiniz.
#
# Sonuç:
#
# Sonuç olarak, market sepeti analizi yapmak için Apriori algoritmasını kullandık ve 50 farklı ürünün bir arada satın alındığında hangi ürünlerin bir arada satın alındığını analiz ettik. Bu analiz, işletmelerin müşteri davranışlarını anlamalarına ve ürünlerini müşteri ihtiyaçlarına göre düzenlemelerine yardımcı olabilir. Bu sayede, müşterilerin ihtiyaçlarını daha iyi karşılayan ve daha fazla satış yapabilen bir işletme olabilirsiniz.
#
#
#
# MLxtend kütüphanesi, market sepeti analizi ve Apriori algoritmasının uygulanması için kullanılan yaygın bir Python kütüphanesidir. Bu kütüphane, market sepeti analizinde kullanılan Apriori algoritması için fonksiyonlar sağlar.
#
# MLxtend kütüphanesi, Apriori algoritması için birkaç farklı çıktı verir. Bu çıktılar arasında şunlar bulunur:
#
# Frequent Itemsets: Bu, belirli bir minimum destek seviyesine sahip olan öğelerin bir arada görünme sıklıklarını gösteren bir çıktıdır. Yani, bu çıktı, belirli bir destek seviyesinin üzerindeki öğelerin bir arada ne sıklıkta görüldüğünü gösterir.
#
# Association Rules: Bu çıktı, Apriori algoritmasının asıl amacı olan bir öğenin varlığı durumunda diğer öğelerin ne sıklıkla görüldüğünü gösterir. Bu çıktı, "destek" ve "güven" kavramlarına dayanır. Destek, bir ürün kombinasyonunun genel olarak ne kadar sıklıkta görüldüğünü gösterirken, güven, belirli bir ürün kombinasyonunun içindeki bir ürünün ne sıklıkla görüldüğünü gösterir.
#
# Öteki İstatistiksel Özellikler: Bu özellikler arasında destek, güven ve lift gibi kavramlar yer alır. Destek, bir kuralın ne kadar sıklıkla görüldüğünü gösterirken, güven, bir ürün kombinasyonunun içindeki bir ürünün ne sıklıkla görüldüğünü gösterir. Lift ise, iki ürünün birlikte satın alınma olasılığının, bağımsız olarak satın alma olasılıklarına göre ne kadar arttığını gösterir.
#
# Bu çıktılar, işletmelerin müşterilerin davranışlarını anlamalarına ve ürünlerini müşteri ihtiyaçlarına göre düzenlemelerine yardımcı olabilir. Bu sayede, müşterilerin ihtiyaçlarını daha iyi karşılayan ve daha fazla satış yapabilen bir işletme olabilirsiniz.
#
#
#
#
#
#
#
#
# ------------------------------------------------------------------
# PMDARIMA kütüphanesi, otomatik zaman serisi modelleme için kullanılan bir Python kütüphanesidir. Bu kütüphane, Auto ARIMA ve SARIMAX algoritmaları için fonksiyonlar sağlar.
#
# Auto ARIMA algoritması, zaman serileri verilerindeki trend, mevsimsellik ve gürültüyü otomatik olarak belirlemek için kullanılan bir makine öğrenimi algoritmasıdır. Bu algoritma, en iyi modeli belirlemek için birden fazla iterasyon yapar ve belirli bir performans ölçütünü kullanarak en iyi modeli seçer. Auto ARIMA algoritması, model oluşturma sürecinde kullanılan parametrelerin (örneğin, ARIMA(p,d,q) parametreleri) otomatik olarak belirlenmesi sayesinde modelleme sürecini kolaylaştırır.
#
# SARIMAX (Seasonal AutoRegressive Integrated Moving Average with eXogenous regressors) algoritması ise, zaman serileri verilerindeki trend, mevsimsellik ve gürültüyü modellemek için kullanılan bir makine öğrenimi algoritmasıdır. Bu algoritma, Auto ARIMA algoritması gibi, bir zaman serisi verisi üzerinde belirli bir performans ölçütüne dayalı olarak en iyi modeli otomatik olarak seçer. Ancak SARIMAX algoritması, Auto ARIMA algoritmasından farklı olarak, exogenous değişkenleri de dahil edebilir. Exogenous değişkenler, zaman serisindeki değişkenlerin yanı sıra dışsal faktörlerin de modelleme sürecine dahil edilmesine olanak tanır.
#
# Auto ARIMA algoritmasının çıktıları arasında, en iyi modelin parametreleri (p, d, q), mevsimsel parametreler (P, D, Q, s), en düşük AIC, BIC ve HQIC değerleri gibi bilgiler yer alır.
#
# SARIMAX algoritması ise, otomatik olarak seçilen en iyi modelin parametreleri (p, d, q, P, D, Q, s), modelin tahminleri, modelin öğrenme sürecindeki hatalar, modelin doğruluğunu ölçmek için kullanılan metrikler ve tahmin aralıkları gibi bilgileri sağlar.
#
# Bu çıktılar, işletmelerin geçmiş verileri analiz ederek gelecekteki satışları tahmin etmelerine ve iş kararlarını buna göre planlamalarına yardımcı olabilir.

# %%
import pandas as pd 
import pyodbc

# bağlantı parametreleri
DRIVER   = "SQL Server"
SERVER   = "wokssql99p"
DATABASE = "IMSDAS_PROJECT_TURKEY_PHARMATREND_MONTHLY"


conn = pyodbc.connect(f'Driver={DRIVER};'
                      f'Server={SERVER};'
                      f'Database={DATABASE};'
                      'Trusted_Connection=yes;')


query = """

/****** Script for SelectTopNRows command from SSMS  ******/
SELECT top 200000
        [Period]
      ,[InvoiceNumber]
      ,[UniverseCode]
      ,[InvoiceDate]
      ,[Price]
      ,[Factor]
      ,[Bonus]
      ,[PFC]
      ,[NewName]
      ,[Bolge]
  FROM [IMSDAS_PROJECT_TURKEY_PHARMATREND_MONTHLY].[dbo].[MertAprioriData1]


"""

data = pd.read_sql(query,conn)
# Out:
# C:\Users\u1143337\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py:762: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
data
# Out:
#           Period InvoiceNumber UniverseCode         InvoiceDate   Price  \
# 0       20210401       3106656      0023703 2021-04-27 17:51:47   23.17
# 1       20210401       3106680      0023703 2021-04-28 09:47:36   23.17
# 2       20210401        353484      0050051 2021-04-06 15:27:14   13.96
# 3       20210401        353484      0050051 2021-04-06 15:27:14   11.09
# 4       20210401        353485      0050051 2021-04-06 15:28:43  110.66
# ...          ...           ...          ...                 ...     ...
# 199995  20210401        212736      0020307 2021-04-14 10:49:23   17.90
# 199996  20210401        212737      0020307 2021-04-14 10:53:28   27.96
# 199997  20210401        212738      0020307 2021-04-14 10:55:43  117.26
# 199998  20210401        212739      0020307 2021-04-14 10:59:18   22.90
# 199999  20210401        212741      0020307 2021-04-14 11:01:19   23.17
#
#         Factor  Bonus      PFC                                NewName  \
# ...

# %%
data_new = data[['InvoiceNumber', 'UniverseCode', 'InvoiceDate', 'NewName',"Factor"]]

# %%
data_new.columns = ["InvoiceNumber","ShopNumber","InvoiceDate","PRODUCT_NAME","FACTOR"]
data_new
# Out:
#        InvoiceNumber ShopNumber         InvoiceDate  \
# 0            3106656    0023703 2021-04-27 17:51:47
# 1            3106680    0023703 2021-04-28 09:47:36
# 2             353484    0050051 2021-04-06 15:27:14
# 3             353484    0050051 2021-04-06 15:27:14
# 4             353485    0050051 2021-04-06 15:28:43
# ...              ...        ...                 ...
# 199995        212736    0020307 2021-04-14 10:49:23
# 199996        212737    0020307 2021-04-14 10:53:28
# 199997        212738    0020307 2021-04-14 10:55:43
# 199998        212739    0020307 2021-04-14 10:59:18
# 199999        212741    0020307 2021-04-14 11:01:19
#
#                                  PRODUCT_NAME  FACTOR
# 0            KLAVUNAT FILM TAB BID 1000 MG 14     1.0
# 1            KLAVUNAT FILM TAB BID 1000 MG 14     1.0
# 2       ILIADIN NOSE SPRAY .02 % PAED 10 ML 1     1.0
# 3            A FERIN PLUS SYRUP PAED 100 ML 1     1.0
# 4             KEPPRA SOLUTION 100 MG 300 ML 1     1.0
# ...

# %%
old_names  = list(data_new.PRODUCT_NAME.value_counts().index[:50])
old_names
# Out:
# ['PAROL TABLETS 500 MG 20',
#  'CORASPIN ENTER.C.TABS 100 MG 30',
#  'ARVELES FILM TABLETS 25 MG 20',
#  'PAROL TABLETS 500 MG 30',
#  'DOLOREX COATED TABLETS 50 MG 20',
#  'ECOPIRIN ENTER.C.TABS 100 MG 30',
#  'NEXIUM ENTER.C.TABS 40 MG 28',
#  'MAJEZIK FILM TABLETS 100 MG 15',
#  'LANSOR CAP MICROPEL 30 MG 28',
#  'AUGMENTIN FILM TAB BID 1000 MG 14',
#  'DEVIT D3 DROPS 50 K 15 ML 1',
#  'TRAVAZOL CREAM 15 G 1',
#  'BENEXOL B12 FILM TABLETS 30',
#  'PANTO ENTER.C.TABS 40 MG 28',
#  'A FERIN FILM TABLETS FORT 30',
#  'ENJEKTOR CESITLI SYRINGE 2 ML 1',
#  'COLEDAN DROPS 15 K /1ML 10 ML 1',
#  'BELOC TABS ZOK SR 50 MG 20',
#  'CALPOL SUSPENSION 120 MG 150 ML 1',
#  'DEVIT D3 AMPOULE INTRAMUSCULAR 300 K 1 ML 1',
#  'ASPIRIN TABLETS 500 MG 20',
#  'THERAFLU FILM TABLETS FORT 20',
#  'NUROFEN COLD+FLU TABLETS 24',
#  'GLIFOR FILM TABLETS 1000 MG 100',
#  'AUGMENTIN FILM TAB BID 1000 MG 10',
#  'ECOPIRIN PRO ENTERIC TABLETS 81 MG 30',
#  'CABRAL FILM TABLETS 400 MG 24',
# ...

# %%
products = [
    "Stellar Lipstick",
    "Proline Shampoo",
    "Classic Coffee Mug",
    "Earthy Tote Bag",
    "Fusion Blush Brush",
    "Elite Facial Cream",
    "Sunrise Yoga Mat",
    "Fusion Salad Bowl",
    "Aqua Body Wash",
    "Urban Backpack",
    "Fusion Hair Straightener",
    "Pacific Trail Hiking Shoes",
    "Classic Bedding Set",
    "Crimson Lip Gloss",
    "Belle Earrings",
    "Arctic Cooling Towel",
    "Fusion Juice Extractor",
    "Classic Fleece Blanket",
    "Coastal Sandals",
    "Starry Night Scarf",
    "Fusion Hand Mixer",
    "Island Tumbler",
    "Elite Eyeshadow Palette",
    "Mountain Biking Gloves",
    "Lavender Scented Candle",
    "Classic Bathrobe",
    "Fusion Yoga Block",
    "Zen Tea Set",
    "Artisanal Cheese Board",
    "Elite Hair Dryer",
    "Electric Wine Opener",
    "Classic Dinnerware Set",
    "Coastal Beach Bag",
    "Fusion Food Processor",
    "Enchanted Forest Wall Art",
    "Iconic Sunglasses",
    "Sunflower Seed Butter",
    "Elite Curling Iron",
    "Classic Throw Pillow",
    "Cityscape Umbrella",
    "Fusion Blender",
    "Firefly String Lights",
    "Bountiful Garden Gloves",
    "Elite Flat Iron",
    "Vibrant Water Bottle",
    "Classic Apron",
    "High Sierra Backpack",
    "Fusion Toaster",
    "Soothing Aromatherapy Oil",
    "Coastal Serving Tray"
]

# %%
dictionary = dict(zip(old_names,products))

# %%
def replace(name):
    if name in set(old_names):
        return dictionary[name]
    else:
        return "MISC"
        

data_new.PRODUCT_NAME = data_new.PRODUCT_NAME.apply(replace)

print(data_new)
# Out:
#        InvoiceNumber ShopNumber         InvoiceDate PRODUCT_NAME  FACTOR
# 0            3106656    0023703 2021-04-27 17:51:47         MISC     1.0
# 1            3106680    0023703 2021-04-28 09:47:36         MISC     1.0
# 2             353484    0050051 2021-04-06 15:27:14         MISC     1.0
# 3             353484    0050051 2021-04-06 15:27:14         MISC     1.0
# 4             353485    0050051 2021-04-06 15:28:43         MISC     1.0
# ...              ...        ...                 ...          ...     ...
# 199995        212736    0020307 2021-04-14 10:49:23         MISC     1.0
# 199996        212737    0020307 2021-04-14 10:53:28         MISC     1.0
# 199997        212738    0020307 2021-04-14 10:55:43         MISC     1.0
# 199998        212739    0020307 2021-04-14 10:59:18         MISC     1.0
# 199999        212741    0020307 2021-04-14 11:01:19         MISC     1.0
#
# [200000 rows x 5 columns]
# ...

# %%
data_new = data_new.drop_duplicates()
data_new.PRODUCT_NAME.value_counts()
# Out:
# MISC                          85872
# Stellar Lipstick               2918
# Classic Coffee Mug             2579
# Earthy Tote Bag                2569
# Proline Shampoo                2543
# Fusion Blush Brush             2055
# Elite Facial Cream             1214
# Sunrise Yoga Mat               1154
# Fusion Salad Bowl              1115
# Aqua Body Wash                 1009
# Urban Backpack                  985
# Fusion Hair Straightener        891
# Pacific Trail Hiking Shoes      844
# Classic Bedding Set             793
# Belle Earrings                  768
# Crimson Lip Gloss               740
# Fusion Juice Extractor          735
# Coastal Sandals                 725
# Arctic Cooling Towel            672
# Elite Eyeshadow Palette         651
# Island Tumbler                  649
# Fusion Hand Mixer               637
# Lavender Scented Candle         628
# Mountain Biking Gloves          609
# Fusion Yoga Block               576
# Classic Bathrobe                561
# ...

# %%
data_new["InvoiceID"] = data_new.groupby(['InvoiceNumber', 'ShopNumber', 'InvoiceDate']).ngroup()
# Out:
# C:\Users\u1143337\AppData\Local\Temp\ipykernel_20160\1618317443.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_new["InvoiceID"] = data_new.groupby(['InvoiceNumber', 'ShopNumber', 'InvoiceDate']).ngroup()

# %%
data_to_save = data_new[["InvoiceID","PRODUCT_NAME","FACTOR"]].sort_values("PRODUCT_NAME")


data_to_save['InvoiceID'] = data_to_save["InvoiceID"].apply(lambda x: hash(str(x)))
# data_to_save.to_excel("market_sales_data.xlsx",index=False)

# %%
data_to_save['InvoiceID'] = data_to_save["InvoiceID"].apply(lambda x: hash(x))
data_to_save
# Out:
#                   InvoiceID    PRODUCT_NAME  FACTOR
# 21981    654330281889562638  Aqua Body Wash     1.0
# 142635  2261609909909484341  Aqua Body Wash     1.0
# 142504  1684634057111078156  Aqua Body Wash     1.0
# 65433    565524657091356777  Aqua Body Wash     1.0
# 65450  -1845938136934233158  Aqua Body Wash     1.0
# ...                     ...             ...     ...
# 30483   1062102062473243221     Zen Tea Set     1.0
# 167174  -517305297054070507     Zen Tea Set     1.0
# 78605   1025120903050891488     Zen Tea Set     1.0
# 59923   -586938791097213131     Zen Tea Set     1.0
# 49456  -1786351862477866689     Zen Tea Set     1.0
#
# [125053 rows x 3 columns]

# %%
sales_data = data_new[["InvoiceID","PRODUCT_NAME"]].groupby('InvoiceID')["PRODUCT_NAME"].apply(list).reset_index()
sales_data
# Out:
#        InvoiceID                                       PRODUCT_NAME
# 0              0                         [Elite Facial Cream, MISC]
# 1              1  [MISC, Mountain Biking Gloves, Elite Facial Cr...
# 2              2                                             [MISC]
# 3              3                                             [MISC]
# 4              4                                             [MISC]
# ...          ...                                                ...
# 97361      97361                          [Fusion Salad Bowl, MISC]
# 97362      97362                       [MISC, Coastal Serving Tray]
# 97363      97363                                             [MISC]
# 97364      97364                                             [MISC]
# 97365      97365                    [Lavender Scented Candle, MISC]
#
# [97366 rows x 2 columns]

# %%
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules


te = TransactionEncoder()
one_hot = te.fit_transform(sales_data["PRODUCT_NAME"])
one_hot_df = pd.DataFrame(one_hot, columns=te.columns_)

one_hot_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20188\1795724054.py in <cell line: 6>()
#       4
#       5 te = TransactionEncoder()
# ----> 6 one_hot = te.fit_transform(sales_data["PRODUCT_NAME"])
#       7 one_hot_df = pd.DataFrame(one_hot, columns=te.columns_)
#       8
#
# NameError: name 'sales_data' is not defined

# %%
freq_itemsets = apriori(one_hot_df, min_support=0.0001, use_colnames=True)

# %%
rules = association_rules(freq_itemsets, metric='lift', min_threshold=1)

# %%
rules

# %%
top_rules = rules.nlargest(n=10, columns='lift')

plt.barh(range(len(top_rules)), top_rules['lift'], color='b', alpha=0.6)
plt.yticks(range(len(top_rules)), top_rules['antecedents'] + ' => ' + top_rules['consequents'])
plt.xlabel('Lift')
plt.ylabel('Association Rule')
plt.title('Top 10 Association Rules by Lift')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20188\2831578216.py in <cell line: 1>()
# ----> 1 top_rules = rules.nlargest(n=10, columns='lift')
#       2
#       3 plt.barh(range(len(top_rules)), top_rules['lift'], color='b', alpha=0.6)
#       4 plt.yticks(range(len(top_rules)), top_rules['antecedents'] + ' => ' + top_rules['consequents'])
#       5 plt.xlabel('Lift')
#
# NameError: name 'rules' is not defined

# %% [markdown]
# # FORECAST

# %%
QUERY ="""

/****** Script for SelectTopNRows command from SSMS  ******/
SELECT [InvoiceNumber]
      ,[UniverseCode]
      ,[InvoiceDate]
      ,[PFC] as PRODUCT_NAME

  FROM [IMSDAS_PROJECT_TURKEY_PHARMATREND_MONTHLY].[dbo].[MertAprioriData1]
  WHERE PFC = 0600311
  
"""


sunscreen = pd.read_sql(QUERY,conn)
sunscreen.PRODUCT_NAME = "SunShield Pro+"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20188\3192495577.py in <cell line: 18>()
#      16
#      17
# ---> 18 sunscreen = pd.read_sql(QUERY,conn)
#      19 sunscreen.PRODUCT_NAME = "SunShield Pro+"
#
# NameError: name 'conn' is not defined

# %%
sunscreen.columns = ["Invoice","Shop","DATE","PRODUCT_NAME"]

sunscreen['DATE'] = sunscreen['DATE'].dt.strftime('%Y-%m-%d')

sunscreen["DATE"] = pd.to_datetime(sunscreen['DATE'])

# %%
sunscreen['Invoice'] = sunscreen["Invoice"].apply(lambda x: hash(x))
sunscreen["Shop"] = sunscreen["Shop"].apply(lambda x : hash(x))
# Out:
# Timestamp('2021-07-06 00:00:00')

# %%
sunscreen = pd.read_excel("SUNSCREEN_forecast.xlsx")

monthly_sales = sunscreen.groupby(pd.Grouper(key="DATE", freq="M"))["PRODUCT_NAME"].count()

# %%
monthly_sales["2021-06-30"] = 320
monthly_sales["2021-10-31"] = 100
monthly_sales.to_excel("monthly_sales.xlsx")

# %%
sunscreen.to_excel("SUNSCREEN_forecast.xlsx",index = False)

# %%
monthly_sales.plot()
# Out:
# <AxesSubplot: xlabel='DATE'>

# %%
monthly_sales
# Out:
# DATE
# 2021-01-31     41
# 2021-02-28     66
# 2021-03-31    117
# 2021-04-30    191
# 2021-05-31    301
# 2021-06-30    320
# 2021-07-31    280
# 2021-08-31    177
# 2021-09-30    124
# 2021-10-31    100
# 2021-11-30     90
# 2021-12-31     93
# Freq: M, Name: PRODUCT_NAME, dtype: int64

# %%
# create a new pandas date range for the previous 5 years
import numpy as np


date_range = pd.date_range(end=pd.Timestamp.today(), periods=121, freq='M')[:-1][::-1]

rising_trend = np.array([1.1*i for i in range(120)])

rising_trend

# create a new pandas series with the same values for each month
previous_years_sales = pd.Series([41, 66, 117, 191, 301, 320, 280, 177, 124, 100, 90, 93] * 10, index=date_range)

noise = np.random.randint(low=-10, high=40, size=len(previous_years_sales))
previous_years_sales_with_noise = previous_years_sales[::-1].rename("SALES") + noise  + rising_trend + 100


previous_years_sales_with_noise.plot()
# Out:
# <AxesSubplot: >

# %%
previous_years_sales_with_noise.rename("SALES").to_excel("monthly_sales.xlsx")

# %%
from pmdarima.arima import auto_arima

from statsmodels.tsa.seasonal import seasonal_decompose

#decomposition
decomposition = seasonal_decompose(x = previous_years_sales_with_noise,
                                   model = 'additive',
                                   period = 12)
decomposition.plot();

# %%
#forecasting model
test_months  = 15

train = previous_years_sales_with_noise[:-test_months]
test = previous_years_sales_with_noise[-test_months:]

model = auto_arima(y = train,
                   #X = train_exog,
                   m = 12,
                   seasonal = True,
                   stepwise = False)

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  SARIMAX Results
# ...
# Dep. Variable:                          y   No. Observations:                  105
# Model:             SARIMAX(1, 1, [1], 12)   Log Likelihood                -389.147
# Date:                    Thu, 09 Mar 2023   AIC                            786.293
# Time:                            20:48:16   BIC                            796.424
# Sample:                        02-28-2013   HQIC                           790.384
#                              - 10-31-2021
# Covariance Type:                      opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     15.8616      2.443      6.494      0.000      11.074      20.649
# ar.S.L12      -0.1568      0.181     -0.868      0.385      -0.511       0.197
# ...

# %%
preds = model.predict(n_periods= test_months+15).rename("SARIMAX")

monthly_sales.plot(legend = True)
preds.plot(legend=True,alpha = 0.7)
# Out:
# <AxesSubplot: >
